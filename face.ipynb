# %% [markdown]
# <a href="https://colab.research.google.com/github/ashik950/Student-Database-Management-System/blob/master/face.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread('/content/pexels-ibadat-singh-2586823.jpg')
img
# Out:
# array([[[ 72,  81,  85],
#         [ 62,  71,  75],
#         [ 47,  56,  60],
#         ...,
#         [ 50,  75,  79],
#         [ 52,  77,  81],
#         [ 61,  86,  90]],
#
#        [[ 62,  71,  75],
#         [ 63,  72,  76],
#         [ 55,  64,  68],
#         ...,
#         [ 71,  96, 100],
#         [ 51,  76,  80],
#         [ 50,  75,  79]],
#
#        [[ 51,  60,  64],
#         [ 58,  67,  71],
#         [ 54,  63,  67],
#         ...,
#         [ 67,  92,  96],
#         [ 45,  70,  74],
#         [ 53,  78,  82]],
#
#        ...,
#
#        [[ 19,  42,  27],
#         [ 20,  43,  28],
#         [ 24,  47,  33],
#         ...,
#         [ 31,  64,  49],
#         [ 36,  69,  54],
#         [ 32,  65,  50]],
#
#        [[ 22,  45,  30],
#         [ 22,  45,  30],
#         [ 24,  47,  33],
#         ...,
#         [ 34,  67,  52],
#         [ 41,  74,  59],
#         [ 35,  68,  53]],
#
#        [[ 28,  51,  36],
#         [ 24,  47,  32],
#         [ 20,  43,  29],
# ...

# %%
cv2_imshow(img)
cv2.waitKey()

# %%
img.shape
# Out:
# (5000, 4000, 3)

# %%
img = cv2.imread('/content/obama-face.png',1)
cv2_imshow(img)
cv2.waitKey
# Out:
# <PIL.Image.Image image mode=RGB size=860x759 at 0x7FDF5DE62980>
# <function waitKey>

# %%
import matplotlib.pyplot as plt
img =cv2.cvtColor(img, cv2.COLOR_BGR2RGBA)
plt.imshow(img)

# %% [markdown]
# # New Section
